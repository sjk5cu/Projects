# %%
import numpy as np
import pandas as pd
import sqlite3

# %% [markdown]
# # Open a connection to the database file

# %%
con = sqlite3.connect("/Users/stephenkullman/Desktop/Python/Python for Data Science UCSD Edx/Week-7-MachineLearning/database.sqlite")

# %%
player = pd.read_sql_query("SELECT * FROM Player_Attributes", con)

# %% [markdown]
# Let's see what we have

# %%
player.head()
# Out:
#    id  player_fifa_api_id  player_api_id                 date  overall_rating  \
# 0   1              218353         505942  2016-02-18 00:00:00            67.0
# 1   2              218353         505942  2015-11-19 00:00:00            67.0
# 2   3              218353         505942  2015-09-21 00:00:00            62.0
# 3   4              218353         505942  2015-03-20 00:00:00            61.0
# 4   5              218353         505942  2007-02-22 00:00:00            61.0
#
#    potential preferred_foot attacking_work_rate defensive_work_rate  crossing  \
# 0       71.0          right              medium              medium      49.0
# 1       71.0          right              medium              medium      49.0
# 2       66.0          right              medium              medium      49.0
# 3       65.0          right              medium              medium      48.0
# 4       65.0          right              medium              medium      48.0
#
# ...

# %%
team = pd.read_sql_query("SELECT * FROM Team", con)
team.head()
# Out:
#    id  team_api_id  team_fifa_api_id     team_long_name team_short_name
# 0   1         9987             673.0           KRC Genk             GEN
# 1   2         9993             675.0       Beerschot AC             BAC
# 2   3        10000           15005.0   SV Zulte-Waregem             ZUL
# 3   4         9994            2007.0   Sporting Lokeren             LOK
# 4   5         9984            1750.0  KSV Cercle Brugge             CEB

# %%
team_attrib = pd.read_sql_query("SELECT * FROM Team_Attributes", con)
team_attrib.head()
# Out:
#    id  team_fifa_api_id  team_api_id                 date  buildUpPlaySpeed  \
# 0   1               434         9930  2010-02-22 00:00:00                60
# 1   2               434         9930  2014-09-19 00:00:00                52
# 2   3               434         9930  2015-09-10 00:00:00                47
# 3   4                77         8485  2010-02-22 00:00:00                70
# 4   5                77         8485  2011-02-22 00:00:00                47
#
#   buildUpPlaySpeedClass  buildUpPlayDribbling buildUpPlayDribblingClass  \
# 0              Balanced                   NaN                    Little
# 1              Balanced                  48.0                    Normal
# 2              Balanced                  41.0                    Normal
# 3                  Fast                   NaN                    Little
# 4              Balanced                   NaN                    Little
#
# ...

# %%
player_ids = pd.read_sql_query("SELECT * FROM Player", con)
player_ids.head()
# Out:
#    id  player_api_id         player_name  player_fifa_api_id  \
# 0   1         505942  Aaron Appindangoye              218353
# 1   2         155782     Aaron Cresswell              189615
# 2   3         162549         Aaron Doran              186170
# 3   4          30572       Aaron Galindo              140161
# 4   5          23780        Aaron Hughes               17725
#
#               birthday  height  weight
# 0  1992-02-29 00:00:00  182.88     187
# 1  1989-12-15 00:00:00  170.18     146
# 2  1991-05-13 00:00:00  170.18     163
# 3  1982-05-08 00:00:00  182.88     198
# 4  1979-11-08 00:00:00  182.88     154

# %% [markdown]
# # Querying

# %% [markdown]
# Who are the highest rated players?

# %%
myquery = ''' 

SELECT player_name, AVG(overall_rating) as mean_rating
FROM Player_Attributes
INNER JOIN Player p
    ON p.player_api_id = Player_Attributes.player_api_id
GROUP BY player_name
ORDER BY mean_rating DESC

''' 

pd.read_sql_query(myquery, con=con)[0:10]
# Out:
#           player_name  mean_rating
# 0        Lionel Messi    92.192308
# 1   Cristiano Ronaldo    91.280000
# 2       Franck Ribery    88.458333
# 3      Andres Iniesta    88.320000
# 4  Zlatan Ibrahimovic    88.285714
# 5        Arjen Robben    87.840000
# 6      Xavi Hernandez    87.636364
# 7        Wayne Rooney    87.222222
# 8       Iker Casillas    86.954545
# 9        Philipp Lahm    86.733333

# %% [markdown]
# What is the win/loss record for each team over the 8 seasons?

# %%
matches = pd.read_sql_query("SELECT * FROM Match", con)

# %%
matches.head()
# Out:
#    id  country_id  league_id     season  stage                 date  \
# 0   1           1          1  2008/2009      1  2008-08-17 00:00:00
# 1   2           1          1  2008/2009      1  2008-08-16 00:00:00
# 2   3           1          1  2008/2009      1  2008-08-16 00:00:00
# 3   4           1          1  2008/2009      1  2008-08-17 00:00:00
# 4   5           1          1  2008/2009      1  2008-08-16 00:00:00
#
#    match_api_id  home_team_api_id  away_team_api_id  home_team_goal  ...  \
# 0        492473              9987              9993               1  ...
# 1        492474             10000              9994               0  ...
# 2        492475              9984              8635               0  ...
# 3        492476              9991              9998               5  ...
# 4        492477              7947              9985               1  ...
#
#     SJA   VCH   VCD   VCA   GBH   GBD   GBA   BSH   BSD   BSA
# ...

# %%
myquery2 = ''' 

SELECT home_team_api_id, team_long_name, SUM(home_team_goal>away_team_goal) AS win, SUM(home_team_goal < away_team_goal) AS loss, SUM(home_team_goal = away_team_goal) AS draw
FROM Match
INNER JOIN Team t
    ON t.team_api_id = Match.home_team_api_id
GROUP BY team_long_name
ORDER BY win DESC
''' 

pd.read_sql_query(myquery2, con=con)
# Out:
#      home_team_api_id         team_long_name  win  loss  draw
# 0                8634           FC Barcelona  131     9    12
# 1                8633         Real Madrid CF  129    12    11
# 2                9925                 Celtic  120     9    23
# 3               10260      Manchester United  116    20    16
# 4                8456        Manchester City  113    21    18
# ..                ...                    ...  ...   ...   ...
# 291              9912  DSC Arminia Bielefeld    2     7     8
# 292            108893       AC Arles-Avignon    2    11     6
# 293              8457   Dunfermline Athletic    1    11     7
# 294              7869             Córdoba CF    1    12     6
# 295              8357   SpVgg Greuther Fürth    0    13     4
#
# [296 rows x 5 columns]

# %% [markdown]
# Breaking up the teams into tiers

# %%
myquery3 = ''' 

SELECT home_team_api_id, team_long_name, win, loss, draw, CASE
    WHEN win <27 then 'tier 5'
    WHEN win BETWEEN 27 AND 53 THEN 'tier 4'
    WHEN win BETWEEN 53 AND 79 THEN 'tier 3'
    WHEN win BETWEEN 79 AND 105 THEN 'tier 2'
    WHEN win BETWEEN 105 AND 132 THEN 'tier 1'
    ELSE NULL
    END AS tier
FROM(
SELECT home_team_api_id, team_long_name, SUM(home_team_goal>away_team_goal) AS win, SUM(home_team_goal < away_team_goal) AS loss, SUM(home_team_goal = away_team_goal) AS draw
FROM Match
INNER JOIN Team t
    ON t.team_api_id = Match.home_team_api_id
GROUP BY team_long_name
ORDER BY win DESC
)
''' 

pd.read_sql_query(myquery3, con=con)
# Out:
#      home_team_api_id         team_long_name  win  loss  draw    tier
# 0                8634           FC Barcelona  131     9    12  tier 1
# 1                8633         Real Madrid CF  129    12    11  tier 1
# 2                9925                 Celtic  120     9    23  tier 1
# 3               10260      Manchester United  116    20    16  tier 1
# 4                8456        Manchester City  113    21    18  tier 1
# ..                ...                    ...  ...   ...   ...     ...
# 291              9912  DSC Arminia Bielefeld    2     7     8  tier 5
# 292            108893       AC Arles-Avignon    2    11     6  tier 5
# 293              8457   Dunfermline Athletic    1    11     7  tier 5
# 294              7869             Córdoba CF    1    12     6  tier 5
# 295              8357   SpVgg Greuther Fürth    0    13     4  tier 5
#
# [296 rows x 6 columns]

# %% [markdown]
# Finding play characteristics for each team

# %%
myquery4 = ''' 

SELECT home_team_api_id, AVG(buildUpPlaySpeed),AVG(buildUpPlayDribbling), AVG(buildUpPlayPassing), AVG(chanceCreationPassing), AVG(chanceCreationCrossing), AVG(chanceCreationShooting), AVG(defencePressure), AVG(defenceAggression)
FROM Match
INNER JOIN Team t
    ON t.team_api_id = Match.home_team_api_id
INNER JOIN Team_Attributes ta
    ON ta.team_api_id = Match.home_team_api_id
GROUP BY home_team_api_id


''' 

pd.read_sql_query(myquery4, con=con)
# Out:
#      home_team_api_id  AVG(buildUpPlaySpeed)  AVG(buildUpPlayDribbling)  \
# 0                1601              47.333333                       48.0
# 1                1773              52.000000                       51.0
# 2                1957              47.166667                       54.0
# 3                2033              49.000000                       62.0
# 4                2182              60.333333                       52.5
# ..                ...                    ...                        ...
# 283             10281              52.833333                       42.0
# 284            108893              43.166667                       47.0
# 285            158085              67.000000                       66.0
# 286            208931              56.000000                       45.5
# 287            274581              50.000000                       50.0
#
#      AVG(buildUpPlayPassing)  AVG(chanceCreationPassing)  \
# ...

# %% [markdown]
# Joining two subqueries

# %%
myquery5 = ''' 
SELECT *
FROM(
    SELECT home_team_api_id, team_long_name, win, loss, draw, CASE
    WHEN win <27 then 'tier 5'
    WHEN win BETWEEN 27 AND 53 THEN 'tier 4'
    WHEN win BETWEEN 53 AND 79 THEN 'tier 3'
    WHEN win BETWEEN 79 AND 105 THEN 'tier 2'
    WHEN win BETWEEN 105 AND 132 THEN 'tier 1'
    ELSE NULL
    END AS tier
    FROM(
        SELECT home_team_api_id, team_long_name, SUM(home_team_goal>away_team_goal) AS win, SUM(home_team_goal < away_team_goal) AS loss, SUM(home_team_goal = away_team_goal) AS draw
        FROM Match
        INNER JOIN Team t
            ON t.team_api_id = Match.home_team_api_id
        GROUP BY team_long_name
        ORDER BY win DESC
        )
    ) y   
JOIN(
    SELECT home_team_api_id, AVG(buildUpPlaySpeed),AVG(buildUpPlayDribbling), AVG(buildUpPlayPassing), AVG(chanceCreationPassing), AVG(chanceCreationCrossing), AVG(chanceCreationShooting), AVG(defencePressure), AVG(defenceAggression)
    FROM Match
    INNER JOIN Team t
        ON t.team_api_id = Match.home_team_api_id
    INNER JOIN Team_Attributes ta
        ON ta.team_api_id = Match.home_team_api_id
    GROUP BY home_team_api_id 
    ) z
    ON z.home_team_api_id = y.home_team_api_id


''' 

pd.read_sql_query(myquery5, con=con)
# Out:
#      home_team_api_id         team_long_name  win  loss  draw    tier  \
# 0                8634           FC Barcelona  131     9    12  tier 1
# 1                8633         Real Madrid CF  129    12    11  tier 1
# 2                9925                 Celtic  120     9    23  tier 1
# 3               10260      Manchester United  116    20    16  tier 1
# 4                8456        Manchester City  113    21    18  tier 1
# ..                ...                    ...  ...   ...   ...     ...
# 280              9912  DSC Arminia Bielefeld    2     7     8  tier 5
# 281            108893       AC Arles-Avignon    2    11     6  tier 5
# 282              8457   Dunfermline Athletic    1    11     7  tier 5
# 283              7869             Córdoba CF    1    12     6  tier 5
# 284              8357   SpVgg Greuther Fürth    0    13     4  tier 5
#
#      home_team_api_id  AVG(buildUpPlaySpeed)  AVG(buildUpPlayDribbling)  \
# ...
